# %%
import os

# %%
for x in os.walk("../../experiments/mimic3"):
    print(x)
# Out:
# ('../../experiments/mimic3', ['.ipynb_checkpoints', 'sept29', 'sanity', 'sept28'], [])
# ('../../experiments/mimic3/.ipynb_checkpoints', [], [])
# ('../../experiments/mimic3/sept29', ['version_3', 'version_16', '.ipynb_checkpoints', 'version_11', 'version_12', 'version_10', 'version_20', 'version_19', 'version_7', 'version_6', 'version_9', 'version_4', 'version_13', 'version_8', 'version_15', 'version_5', 'version_14', 'version_2', 'version_1', 'version_18', 'version_0', 'version_17'], [])
# ('../../experiments/mimic3/sept29/version_3', ['checkpoints'], ['hparams.yaml'])
# ('../../experiments/mimic3/sept29/version_3/checkpoints', [], [])
# ('../../experiments/mimic3/sept29/version_16', ['checkpoints'], ['metrics.csv', 'hparams.yaml'])
# ('../../experiments/mimic3/sept29/version_16/checkpoints', [], ['epoch=14-step=1394.ckpt'])
# ('../../experiments/mimic3/sept29/.ipynb_checkpoints', [], [])
# ...
